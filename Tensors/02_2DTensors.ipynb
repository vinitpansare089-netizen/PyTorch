# %%
import torch

x = torch.tensor([
    [10,20,30],
    [40,50,60]
])

# print(x)
# print(x.shape)
# print(x.dtype)
# print(x.ndim)

print(x[0][1])#//20
print(x[0][0])#//10
print(x[1][2])#//60
# Out:
# tensor(20)
# tensor(10)
# tensor(60)
