# %%
import torch

x = torch.tensor([
    [10,20,30],
    [40,50,60]
])

print(x)
print(x.shape)
print(x.dtype)
print(x.ndim)
# Out:
# tensor([[10, 20, 30],
#         [40, 50, 60]])
# torch.Size([2, 3])
# torch.int64
# 2
