# %%
import torch

x = torch.tensor([10,20,30,40,50])

print(x)
print(x.shape)
print(x.dtype)

import numpy as np

n = np.array([10,20,30])

print(n.shape)
# Out:
# tensor([10, 20, 30, 40, 50])
# torch.Size([5])
# torch.int64

# %%
import torch

x = torch.tensor([10,20,30,40,50])

print(x)
print(x.shape)
print(x.dtype)

import numpy as np

n = np.array([10,20,30])

print(n.shape)
print(n.dtype)
# Out:
# tensor([10, 20, 30, 40, 50])
# torch.Size([5])
# torch.int64
# (3,)
# int64
